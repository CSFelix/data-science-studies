# %% [markdown]
# <center>
#     <h1 id='maximum-pooling' style='color:#7159c1'>👁️‍🗨️ Maximum Pooling 👁️‍🗨️</h1>
#     <i>Intensifying Extracted Features</i>
# </center>
#
# ---
#
# This last step in the head intensifies the features, making the model gets just the most useful part of the image (ignoring the most zeros - black pixels - and turning the classification better and faster).

# %%
# ---- Importations ----
import tensorflow as tf # pip install tensorflow
import matplotlib.pyplot as plt # pip install matplotlib
import mplcyberpunk # pip install mplcyberpunk

plt.style.use('cyberpunk')

# ---- Preparing the Image ----
image_path = './datasets/car-feature/car_feature.jpg'
image = tf.io.read_file(image_path)
image = tf.io.decode_jpeg(image)

# ---- Kernel - Edge Filter ----
kernel = tf.constant([
    [-1, -1, -1]
    , [-1, 8, -1]
    , [-1, -1, -1]
], dtype=tf.float32)

# ---- Transforming Image and Batch Compatibility ----
image = tf.image.convert_image_dtype(image, dtype=tf.float32)
image = tf.expand_dims(image, axis=0)
kernel = tf.reshape(kernel, [*kernel.shape, 1, 1])

# ---- Filtering Features (Convolutional Layer) ----
image_filter = tf.nn.conv2d(
    input=image
    , filters=kernel
    , strides=1
    , padding='SAME'
)

# ---- Detecting the Feature (ReLU Layer) ----
image_detect = tf.nn.relu(image_filter)

# ---- Enhancing/Condensing the Features (Max Pooling Layer) ----
image_condense = tf.nn.pool(
    input=image_detect
    , window_shape=(2, 2)
    , pooling_type='MAX'
    , strides=(2,2)
    , padding='SAME' # the output is in the same size of the input
	# padding='VALID', the output is not in the same size of the input (it's in the same size of the padding)
)

# ---- Plotting Results so far ----
plt.figure(figsize=(12, 6))

plt.subplot(141)
plt.title('Input')
plt.axis('off')
plt.imshow(tf.squeeze(image), cmap='gray')

plt.subplot(142)
plt.title('Filtering')
plt.axis('off')
plt.imshow(tf.squeeze(image_filter), cmap='gray')

plt.subplot(143)
plt.title('Detection')
plt.axis('off')
plt.imshow(tf.squeeze(image_detect), cmap='gray')

plt.subplot(144)
plt.title('Condense')
plt.axis('off')
plt.imshow(tf.squeeze(image_condense))

plt.show()

# %% [markdown]
# ---
#
# <h1 id='reach-me' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📫 | Reach Me</h1>
#
# > **Email** - [csfelix08@gmail.com](mailto:csfelix08@gmail.com?)
#
# > **Linkedin** - [linkedin.com/in/csfelix/](https://www.linkedin.com/in/csfelix/)
#
# > **GitHub:** - [CSFelix](https://github.com/CSFelix)
#
# > **Kaggle** - [DSFelix](https://www.kaggle.com/dsfelix)
#
# > **Portfolio** - [CSFelix.io](https://csfelix.github.io/).
