# %% [markdown]
# <center>
#     <h1 id='duplicated-values' style='color:#7159c1'>🔨 Duplicated Values 🔨</h1>
#     <i>Identifying Duplicated Values</i>
# </center>

# %%
# ---- Settings ----
import pandas as pd # pip install pandas
import numpy as np # pip install numpy

np.random.seed(20241801)

# %%
# ---- Reading Dataset ----
catalog_df = pd.read_csv('./datasets/catalog.csv')

# ---- Checking Existence of Duplicated Values ----
#
#	\ False >> there are no duplicated values
#	\ True  >> there are duplicated values
#
catalog_df.duplicated('country_name').any()
# Out:
# True

# %%
# ---- Creating Duplicated DataFrame ----
duplicated_catalog_df = catalog_df[catalog_df.duplicated('country_name')]
duplicated_catalog_df.head()
# Out:
#    id     date time continent_code   country_name country_code state/province  \
# 1  42  3/22/07  NaN            NaN  United States           US           Ohio
# 2  56   4/6/07  NaN            NaN  United States           US   Pennsylvania
# 4  61  4/15/07  NaN            NaN  United States           US       Kentucky
# 5  64  4/20/07  NaN            NaN  United States           US       Kentucky
# 6  67  4/24/07  NaN            NaN  United States           US   South Dakota
#
#    population         city/town  distance  ...  \
# 1       17288  New Philadelphia   3.33522  ...
# 2       15930       Wilkinsburg   2.91977  ...
# 4        6903         Pikeville   5.66542  ...
# 5        6903         Pikeville   0.23715  ...
# 6        2540      Dakota Dunes   2.48033  ...
#
#                                  geolocation  hazard_type  landslide_type  \
# 1  (40.517499999999998, -81.430499999999995)    Landslide       Landslide
# ...

# %% [markdown]
# ---
#
# <h1 id='reach-me' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>📫 | Reach Me</h1>
#
# > **Email** - [csfelix08@gmail.com](mailto:csfelix08@gmail.com?)
#
# > **Linkedin** - [linkedin.com/in/csfelix/](https://www.linkedin.com/in/csfelix/)
#
# > **GitHub:** - [CSFelix](https://github.com/CSFelix)
#
# > **Kaggle** - [DSFelix](https://www.kaggle.com/dsfelix)
#
# > **Portfolio** - [CSFelix.io](https://csfelix.github.io/).
